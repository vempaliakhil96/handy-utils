# %%
# %load_ext autoreload

# %%
# %autoreload
from handy_utils.configuration import load_configuration
from atlassian import Confluence
import nbformat
import pandoc

# %%
config = load_configuration()

# %%
path = '/Users/avempali/Documents/repos/devai-issue-scoping/notebooks/avempali-16-online-issue-scoping-analysis.ipynb'
nbs = nbformat.read(open(path, 'r'), as_version=4)

# %%
from nbconvert.exporters import HTMLExporter

# %%
exporter = HTMLExporter()

# %%
text, _ = exporter.from_notebook_node(nbs)

# %%
# Out:
# {'id': '4777383548',
#  'type': 'page',
#  'status': 'current',
#  'title': 'Test Page',
#  'space': {'id': 4060943559,
#   'key': '~712020f31a52ec6e0b49879847f0d6148c2f18',
#   'alias': '~712020f31a52ec6e0b49879847f0d6148c2f18',
#   'name': 'Akhil Vempali',
#   'type': 'personal',
#   'status': 'current',
#   '_expandable': {'settings': '/rest/api/space/~712020f31a52ec6e0b49879847f0d6148c2f18/settings',
#    'metadata': '',
#    'operations': '',
#    'lookAndFeel': '/rest/api/settings/lookandfeel?spaceKey=~712020f31a52ec6e0b49879847f0d6148c2f18',
#    'identifiers': '',
#    'permissions': '',
#    'roles': '',
#    'icon': '',
#    'description': '',
#    'theme': '/rest/api/space/~712020f31a52ec6e0b49879847f0d6148c2f18/theme',
#    'history': '',
#    'homepage': '/rest/api/content/4060944160'},
#   '_links': {'webui': '/spaces/~712020f31a52ec6e0b49879847f0d6148c2f18',
#    'self': 'https://hello.atlassian.net/wiki/rest/api/space/~712020f31a52ec6e0b49879847f0d6148c2f18'}},
# ...
